# %% [markdown]
# ## Section 3.1
#
# #### #1 - What is an Algotithm?
#
# * An algorithm is a set or series of logical instructions that lead to a desired outcome.
#
# ### #2 - Variable names may not start with certain characters - name two.
#
# * A variable cannot start with a number or non-alphabet character (except for underscore)
#
# ### #3 - What is a Semantic error?
#
# * A semantic error happens when a programmer writes executable code without syntax errors, but the program returns the incorrect outputs due to a typo or misentry or a variable, function, operator, or value.
#
# ### #4 - What is the #1 rule of coding / debugging?
#
# * Complexity is the enemy of efficiency!
#
# ### #5 - List 5 Python reserved words.
#
# * not
# * FALSE
# * if
# * class
# * return

# %%
#6
"""
CARLOS CORTES
I love eating Chengdu regional Chinese cuisine.
Some of my favorite restaraunts of this style are 'Szechuan Imprssion' in Tustin and 'Chengdu Tasts' in Las Vegas.
My dream job is to be a strategic business optimization consultant for local mid-size companies
I want to help empower companies to meet their strategic goals.
"""

# %%
# 7
name, height, sat_score, qualities_list, address_num = "Jonathan", 67.3, 1530, ["Green", 2023, {"bicycle", "two wheels"}, 98.3, [2, 15, 16]], 2951

print(len(name))
print(name[3])

# %%
# 8
savvy = "Learning Data Analytics and Python is Awesome!"

# this section prints a slice and replaces a portion of the string 
print(savvy[5:24])
print(savvy.replace("Awesome", "great"))

# this conditional check identifies if "Python" is present
if "Python" in savvy:
	print("Yes, 'Python' is present.")

# %%
# 9

# this section assigns 3 variables 
name, age, length = "Charlie", "29", "69"

# This variable creates a dynamic string to plug in the varables during print()  
miniBio = "Hi my name is {}, I am {} inches tall and {} years old today."
print(miniBio.format(name, length, float(age)))

# %% [markdown]
# ## Section 3.2

# %%
#10

# copy.deepcopy method needs to be imported 
import copy

# This section of code creates, appends and extend various lists per the instructions
list1 = ["Water", 50.25, 23, ["Tall", {"free", "zero"}, 32], "Jack of all"]
list_to_extend = ["Large", "Iced", "Latte", "oatmilk", 16.0]
list1[1] = 25.125
list1.append("Porcshe 911")
list1.extend(list_to_extend)
# print(list1)
print(f"this list contains {len(list1)} elements.")
list2 = list1[2:5]
print(list2)
list1.extend(list2)
print(list1)
simList = ["A", "B", "C", "D"]
simList.sort()
print(simList)
simList2 = copy.deepcopy(simList)
simList2.sort(reverse=True)
print(simList2, " and ", simList)

# creates/prints a new list from various lists
list4 = list2 + simList
print(list4)

# %%
# 11

a = (5, 10, 15, 20, 25, 30)
b = a * 3
print(b)
print(b[-1])
# b.sort()
# print(b)
c = (b[8:])
print(c)
one, two, three, four = c[0], c[1], c[2], c[3]
print("Here are the 4 unpacked variables: ", one,two,three,four)
d = (50,)
print(d)
e = b + c
print(e)

# %%
#12

# Add a list of fruits to the above set and print the result 
set1 = {"Truck", "Plane", "Train", "Boat"}
fruits = ["Apple","Banana","Peach","Guava"]
set1.update(fruits)
print(set1)

# Add a car element to your set
set1.add("Car")
print(set1)

# Create a 2nd set with a few odd items
set2 = {"nose", "tongue", "hair", "eyes"}

# Save the union of 1st set and 2nd set to a 3rd set
set3 = set1.union(set2)
print(set3)

# Pop an element from the 2nd set, and print the remainder of the set
pop1 = set2.pop()
print(set2)

# Clear the 1st set and print the result
set1.clear()
print(set1)

# Discard an element, and remove another element from the 3rd set
set3.remove("eyes")
set3.discard("nose")

# Print the remainder of the 3rd set
print(set3)

# %%
# 13

# copy.deepcopy needs to b imported
import copy

# Create a dictionary with at least 5 values of different data types
dict1 = {
    "large":24.0,
    "small":12,
    "medium":"middle",
    "15.0":"quince",
    "25":25.0,
    "name":"John"
}

# Print out 1 value
print(dict1["large"])

# Replace any one value in your dictionary with your name
dict1.update({"large":"Carlos"})

# Add your favorite color to the dictionary
dict1.update({"Fav Color":"Navy Blue"})

# Add a list, tuple or set to your dictionary
dict1.update({"Fav Numbers":[21, 32, 7, 0.5]})

# Print a list of the dictionary keys
print(dict1.keys())

# Print a list of the dictionary values
print(dict1.values())

# Copy your 1st dictionary into a 2nd dictionary
dict2 = copy.deepcopy(dict1)

# Pop an item from the 2nd dictionary, and print the dictionary
dict2.pop("large")

# Remove all the elements from the 2nd dictionary and print the result
dict2.clear()
print(dict2)
